# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd  /content/drive/'My Drive'/dfc2021-msd-baseline-master
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1EwWLQLp95HN0M3kHRSu3tUFl7rMB5BOy/dfc2021-msd-baseline-master

# %%
# !pip install rasterio fiona segmentation-models-pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.3 MB 304 kB/s
# ...
#      |████████████████████████████████| 16.7 MB 62.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 9.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 376 kB 62.0 MB/s
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=f0bb9a736cdc2d688857f3032cd94078dc0aec17210e700eb9563d5e981d12f0
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60966 sha256=00787dcfe58e98a0e4be4c7bd8a18ed541f60d6d27a96f583aa4fe7b4dab2e27
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# ...

# %% [markdown]
# ##UNET - BOTH

# %%
# Training
# !python train.py --input_fn data/splits/train_list_100.csv --output_dir results/unet_both_baseline_nicfi_main/ --save_most_recent --num_epochs 10
# Out:
# Starting DFC2021 baseline training script at 2022-11-19 05:38:38.041166
# The output directory doesn't exist or is empty.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# We will be training with 687 batches per epoch
# Model has 11769091 parameters
#   0% 0/687 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ...

# %%
# Prediction on Validation images 
# !python inference.py --input_fn data/splits/val_list.csv --model_fn results/unet_both_baseline_nicfi_main/most_recent_model.pt --output_dir results/unet_both_baseline_nicfi_main/output/
# Out:
# Starting DFC2021 model inference script at 2022-11-19 06:44:57.403644
# The output directory doesn't exist or is empty.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (0/102) Processing /content/drive/MyDrive/Validation_images/99_2016.tif ... finished in 16.4023 seconds
# (1/102) Processing /content/drive/MyDrive/Validation_images/99_2019.tif ... finished in 17.4843 seconds
# (2/102) Processing /content/drive/MyDrive/Validation_images/015_2016.tif ... finished in 7.0093 seconds
# ...

# %% [markdown]
# ## FCN Both

# %%
# !python train.py --input_fn data/splits/train_list_100.csv --output_dir results/fcn_both_baseline_nicfi_main/ --save_most_recent --model fcn --num_epochs 10
# Out:
# Starting DFC2021 baseline training script at 2022-11-19 07:09:21.966895
# The output directory doesn't exist or is empty.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# We will be training with 687 batches per epoch
# Model has 149699 parameters
#   0% 0/687 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ...

# %%
# !python inference.py --input_fn data/splits/val_list.csv --model_fn results/fcn_both_baseline_nicfi_main/most_recent_model.pt --output_dir results/fcn_both_baseline_nicfi_main/output/ --model fcn
# Out:
# Starting DFC2021 model inference script at 2022-11-19 08:07:04.506322
# The output directory doesn't exist or is empty.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (0/102) Processing /content/drive/MyDrive/Validation_images/99_2016.tif ... finished in 13.0505 seconds
# (1/102) Processing /content/drive/MyDrive/Validation_images/99_2019.tif ... finished in 7.3148 seconds
# (2/102) Processing /content/drive/MyDrive/Validation_images/015_2016.tif ... finished in 7.1463 seconds
# ...

# %% [markdown]
# ###Water

# %%
# !python train.py --input_fn data/splits/train_list_true.csv --output_dir results/unet_both_baseline_nicfi_water/ --save_most_recent --num_epochs 10
# Out:
# Starting DFC2021 baseline training script at 2022-11-24 02:27:00.201336
# The output directory doesn't exist or is empty.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# We will be training with 1225 batches per epoch
# Model has 11769091 parameters
#   0% 0/1225 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# ...

# %%
# !python inference.py --input_fn data/splits/val_list.csv --model_fn results/unet_both_baseline_nicfi_water/most_recent_model.pt --output_dir results/unet_both_baseline_nicfi_water/output/
# Out:
# Starting DFC2021 model inference script at 2022-11-24 04:33:04.933803
# The output directory doesn't exist or is empty.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (0/102) Processing /content/drive/MyDrive/Validation_images/99_2016.tif ... finished in 9.0206 seconds
# (1/102) Processing /content/drive/MyDrive/Validation_images/99_2019.tif ... finished in 7.0159 seconds
# (2/102) Processing /content/drive/MyDrive/Validation_images/015_2016.tif ... finished in 6.9670 seconds
# ...
